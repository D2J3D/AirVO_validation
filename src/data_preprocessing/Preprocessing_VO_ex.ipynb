# %%
import numpy as np
import pandas as pd

# %%
def cut_data(df, num_cols:int):
    return df[df.columns[:num_cols]]

# %%
df = pd.read_csv('./data.csv', sep=',')

# %%
df
# Out:
#                 #timestamp   p_RS_R_x [m]   p_RS_R_y [m]   p_RS_R_z [m]  \
# 0      1403637132888318976       4.631117      -1.786812       0.577113
# 1      1403637132893318912       4.631114      -1.786783       0.577110
# 2      1403637132898319104       4.631111      -1.786751       0.577107
# 3      1403637132903318784       4.631110      -1.786716       0.577103
# 4      1403637132908318976       4.631110      -1.786677       0.577097
# ...                    ...            ...            ...            ...
# 26297  1403637264373318912       4.536302      -1.890576       0.585763
# 26298  1403637264378319104       4.536292      -1.890563       0.585752
# 26299  1403637264383318784       4.536282      -1.890551       0.585740
# 26300  1403637264388318976       4.536266      -1.890536       0.585727
# 26301  1403637264393318912       4.536245      -1.890519       0.585712
#
#         q_RS_w []   q_RS_x []   q_RS_y []   q_RS_z []   v_RS_R_x [m s^-1]  \
# ...

# %%
df_cut = cut_data(df, 8)

# %%
df_cut
# Out:
#                 #timestamp   p_RS_R_x [m]   p_RS_R_y [m]   p_RS_R_z [m]  \
# 0      1403637132888318976       4.631117      -1.786812       0.577113
# 1      1403637132893318912       4.631114      -1.786783       0.577110
# 2      1403637132898319104       4.631111      -1.786751       0.577107
# 3      1403637132903318784       4.631110      -1.786716       0.577103
# 4      1403637132908318976       4.631110      -1.786677       0.577097
# ...                    ...            ...            ...            ...
# 26297  1403637264373318912       4.536302      -1.890576       0.585763
# 26298  1403637264378319104       4.536292      -1.890563       0.585752
# 26299  1403637264383318784       4.536282      -1.890551       0.585740
# 26300  1403637264388318976       4.536266      -1.890536       0.585727
# 26301  1403637264393318912       4.536245      -1.890519       0.585712
#
#         q_RS_w []   q_RS_x []   q_RS_y []   q_RS_z []
# ...

# %%
df_cut.to_csv('./MH_03_gt.txt', sep=',', index=False)
