# %%
import numpy as np
import pandas as pd

# %%
def reduce_dot(df, column_name):
    df[column_name] = df[column_name].str.replace('.', '').astype(int)
    return df

# %%
df = pd.read_csv('./MH_03_traj.txt', sep=' ', header=None, dtype=str)

# %%
df
# Out:
#                         0            1            2            3  \
# 0    1403637130.538319111  0.000000000  0.000000000  1.000000000
# 1    1403637133.988318920  0.033674938  0.279692029  1.150739116
# 2    1403637138.588319063  0.061272401  0.221592032  1.486744835
# 3    1403637139.188318968  0.069119103  0.343660944  1.131256253
# 4    1403637151.588319063  0.206678860  0.875218387  1.440753198
# ..                    ...          ...          ...          ...
# 227  1403637256.538319111  1.979405372  1.908794336  1.365913340
# 228  1403637257.238319159  1.563982087  1.678242986  1.212145283
# 229  1403637257.988318920  1.128463742  1.437447873  1.129482365
# 230  1403637258.788318872  0.665246905  1.408269260  0.988748298
# 231  1403637261.338319063  0.270474670  1.313609266  0.673707276
#
#                 4             5             6            7
# 0    -0.707106781   0.000000000   0.000000000  0.707106781
# 1    -0.723017768   0.024734703  -0.021968284  0.690036880
# ...

# %%
df.iloc[:, 1:] = df.iloc[:, 1:].applymap(lambda x: float(x))

# %%
df
# Out:
#                         0         1         2         3         4         5  \
# 0    1403637130.538319111       0.0       0.0       1.0 -0.707107       0.0
# 1    1403637133.988318920  0.033675  0.279692  1.150739 -0.723018  0.024735
# 2    1403637138.588319063  0.061272  0.221592  1.486745 -0.698595  0.054528
# 3    1403637139.188318968  0.069119  0.343661  1.131256  -0.73525  0.054709
# 4    1403637151.588319063  0.206679  0.875218  1.440753 -0.722594  0.035338
# ..                    ...       ...       ...       ...       ...       ...
# 227  1403637256.538319111  1.979405  1.908794  1.365913 -0.715192  0.013878
# 228  1403637257.238319159  1.563982  1.678243  1.212145 -0.722254  0.005137
# 229  1403637257.988318920  1.128464  1.437448  1.129482 -0.743112 -0.031348
# 230  1403637258.788318872  0.665247  1.408269  0.988748 -0.722964 -0.105661
# 231  1403637261.338319063  0.270475  1.313609  0.673707 -0.735637 -0.107916
#
#             6         7
# 0         0.0  0.707107
# ...

# %%
df[df.columns[0]] = df[df.columns[0]].str.replace('.', '').astype(int)

# %%
df
# Out:
#                        0         1         2         3         4         5  \
# 0    1403637130538319111       0.0       0.0       1.0 -0.707107       0.0
# 1    1403637133988318920  0.033675  0.279692  1.150739 -0.723018  0.024735
# 2    1403637138588319063  0.061272  0.221592  1.486745 -0.698595  0.054528
# 3    1403637139188318968  0.069119  0.343661  1.131256  -0.73525  0.054709
# 4    1403637151588319063  0.206679  0.875218  1.440753 -0.722594  0.035338
# ..                   ...       ...       ...       ...       ...       ...
# 227  1403637256538319111  1.979405  1.908794  1.365913 -0.715192  0.013878
# 228  1403637257238319159  1.563982  1.678243  1.212145 -0.722254  0.005137
# 229  1403637257988318920  1.128464  1.437448  1.129482 -0.743112 -0.031348
# 230  1403637258788318872  0.665247  1.408269  0.988748 -0.722964 -0.105661
# 231  1403637261338319063  0.270475  1.313609  0.673707 -0.735637 -0.107916
#
#             6         7
# 0         0.0  0.707107
# ...

# %%
df.to_csv('./MH_03_airvo.txt', sep=',', index=False)
